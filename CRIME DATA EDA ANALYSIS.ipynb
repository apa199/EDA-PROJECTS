# %%
import pandas as pd

# %%
df1=pd.read_csv("crime_against_children_(State-UT-wise)_2019-2021.csv")
df2=pd.read_csv("crime_against_women_(State-UT-wise)_2019-2021.csv")
df3=pd.read_csv("IPC_crimes_(City-wise)_2019-2021 (1).csv")
df4=pd.read_csv("IPC_crimes_(City-wise)_2019-2021.csv")
df5=pd.read_csv("IPC_crimes_(State-UT-wise)_2019-2021.csv")
df6=pd.read_csv("kidnapping_abduction_(State-UT-wise)_2019-2021.csv")
df7=pd.read_csv("Total_Complaints_Received_2019-2021.csv")
df8=pd.read_csv("violent_crimes_(State-UT-wise)_2021.csv")
df=pd.merge(df1,df2,df3,df4,df5,df6,df7,df8)

# %%
df7['FIR']=df7['#ofFIRs']+df7['#ofOnlineFIRS']

# %%
sns.barplot(data=df7.sort_values('FIR',ascending=False).head(6),y='TypeofComplaints',x='FIR')
# Out:
# <Axes: xlabel='FIR', ylabel='TypeofComplaints'>

# %%
sns.barplot(data=df7.sort_values('#ofComplaints',ascending=False).head(6),y='TypeofComplaints',x='#ofComplaints')
# Out:
# <Axes: xlabel='#ofComplaints', ylabel='TypeofComplaints'>

# %%
df4.head(2)
# Out:
#    S.No       City  2019  2020  2021  Population  RateofCognizableCrimes  \
# 0     1       Agra  6510  6285  5665        17.5                   324.5
# 1     2  Allahabad  5621  5455  4130        12.2                   339.4
#
#    ChargesSheetingRate
# 0                 58.0
# 1                 68.2

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(y='Name',x='RateofViolentCrimes',data=df8.sort_values(by='RateofViolentCrimes',ascending=False).head(6))
# Out:
# <Axes: xlabel='RateofViolentCrimes', ylabel='Name'>

# %%
sns.barplot(y='Name',x='',data=df6.sort_values(by='RateofKidnappingAbduction',ascending=False).head(6))
# Out:
# <Axes: xlabel='RateofKidnappingAbduction', ylabel='Name'>

# %%
import seaborn as sns

# %%
sns.barplot(y='Name',x='RateofCognizableCrimes',data=df5.sort_values(by='RateofCognizableCrimes',ascending=False).head(6))
# Out:
# <Axes: xlabel='RateofCognizableCrimes', ylabel='Name'>

# %%
sns.barplot(y='City',x='RateofCognizableCrimes',data=df4.sort_values(by='RateofCognizableCrimes',ascending=False).head(6))
# Out:
# <Axes: xlabel='RateofCognizableCrimes', ylabel='City'>

# %%
df3.head(2)
# Out:
#    S.No       City  2019  2020  2021  Population  RateofCognizableCrimes  \
# 0     1       Agra  6510  6285  5665        17.5                   324.5
# 1     2  Allahabad  5621  5455  4130        12.2                   339.4
#
#    ChargesSheetingRate
# 0                 58.0
# 1                 68.2

# %%
sns.barplot(y='City',x='RateofCognizableCrimes',data=df3.sort_values(by='RateofCognizableCrimes',ascending=False).head(6))
# Out:
# <Axes: xlabel='RateofCognizableCrimes', ylabel='City'>

# %%
df1.head(2)
# Out:
#    S.No State/UT               Name  2019  2020  2021  midPopulation  \
# 0     1    State     Andhra Pradesh  2524  2648  2669          151.1
# 1     2    State  Arunachal Pradesh   153   113   162            5.9
#
#    RateofCrimeAgainstChildren  ChargesSheetingRate
# 0                        17.7                 93.2
# 1                        27.5                 69.6

# %%
sns.barplot(y='Name',x='RateofCrimeAgainstWomen',data=df2.sort_values(by='RateofCrimeAgainstWomen',ascending=False).head(6))
# Out:
# <Axes: xlabel='RateofCrimeAgainstWomen', ylabel='Name'>

# %%
sns.barplot(y='Name',x='RateofCrimeAgainstChildren',data=df1.sort_values(by='RateofCrimeAgainstChildren',ascending=False).head(6))
# Out:
# <Axes: xlabel='RateofCrimeAgainstChildren', ylabel='Name'>

# %% [markdown]
# # OBSERVATIONS:

# %% [markdown]
# 1. Rate crime against children is highest in Delhi
# 2. Rate crime against Women is highest in Assam
# 3. RateofCognizableCrimes is highest in Rajkot
# 4. RateofCognizableCrimes is highest in Delhi
# 4. RateofViolentCrimes is highest in Assam
# 6. RateofKidnappingAbduction is highest in Delhi
# 7. TypeofComplaints is mostly Written
# 8. FIR is in Written mostly
